# %% [markdown]
# # Plot and save images of the Po river

# %% [markdown]
# Plot and save images to make a gif

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import rasterio
from rasterio.plot import show
from pathlib import Path
import shapely.wkt

# import threebee

pd.set_option('display.max_columns', None)

# %%
import pandas as pd
from IPython.display import display


def left_align(df: pd.DataFrame):
    """Set the input dataframe to have its text cells all left aligned."""
    left_aligned_df = df.style.set_properties(
        **{"text-align": "left", "vertical-align": "top"}
    )
    left_aligned_df = left_aligned_df.set_table_styles(
        [dict(selector="th", props=[("text-align", "left"), ("vertical-align", "top")])]
    )
    return left_aligned_df


def display_full(df: pd.DataFrame):
    """Display an input dataframe by showing all of the cells content, and
    with left alignment of the cells."""

    with pd.option_context(
        "display.max_rows",
        None,
        "display.max_columns",
        None,
        "display.max_colwidth",
        None,
    ):
        display(left_align(df))

# %% [markdown]
# ## Plot the downloaded image of 2022/07/16

# %% [markdown]
# Open metadata csv

# %%
# Get all csv paths
path_to_apiquery = (
    "../sentinelcache/apiquery/"
)
files = Path(path_to_apiquery).glob('*.csv') # get all csvs in your dir.
all_dfs = [pd.read_csv(file,index_col = 0) for file in files]
df_csvs = pd.concat(all_dfs)

# Get all tiff paths
path_to_tiffs = (
    "../sentinelcache/products/"
)
tiffs10m = Path(path_to_tiffs).rglob('*10m.tiff')
df_tiffs = pd.DataFrame({"path" : tiffs10m})
df_tiffs["uuid"] = df_tiffs["path"].apply(lambda x: x.parent.name)

# Merge the info
df_all = pd.merge(df_csvs, df_tiffs, how="left", on="uuid")
df_all.drop_duplicates(inplace=True)

# %%
df_all
# Out:
#                                                  title  \
# 0    S2B_MSIL2A_20220523T100559_N0400_R022_T32TNR_2...
# 1    S2B_MSIL2A_20220523T100559_N0400_R022_T32TPR_2...
# 2    S2B_MSIL2A_20220523T100559_N0400_R022_T32TNQ_2...
# 3    S2B_MSIL2A_20220523T100559_N0400_R022_T32TPQ_2...
# 4    S2A_MSIL2A_20220521T101601_N0400_R065_T32TPR_2...
# ..                                                 ...
# 255  S2A_MSIL2A_20220418T100601_N0400_R022_T32TPQ_2...
# 271  S2B_MSIL2A_20220416T101559_N0400_R065_T32TNR_2...
# 272  S2B_MSIL2A_20220416T101559_N0400_R065_T32TPQ_2...
# 273  S2B_MSIL2A_20220416T101559_N0400_R065_T32TPR_2...
# 274  S2B_MSIL2A_20220416T101559_N0400_R065_T32TNQ_2...
#
#                                                   link  \
# 0    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 1    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 2    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 3    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 4    https://apihub.copernicus.eu/apihub/odata/v1/P...
# ..                                                 ...
# 255  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 271  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 272  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 273  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 274  https://apihub.copernicus.eu/apihub/odata/v1/P...
#
#                                       link_alternative  \
# 0    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 1    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 2    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 3    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 4    https://apihub.copernicus.eu/apihub/odata/v1/P...
# ..                                                 ...
# 255  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 271  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 272  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 273  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 274  https://apihub.copernicus.eu/apihub/odata/v1/P...
#
#                                              link_icon  \
# 0    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 1    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 2    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 3    https://apihub.copernicus.eu/apihub/odata/v1/P...
# 4    https://apihub.copernicus.eu/apihub/odata/v1/P...
# ..                                                 ...
# 255  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 271  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 272  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 273  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 274  https://apihub.copernicus.eu/apihub/odata/v1/P...
#
#                
# 3                 16.958424         0.232750                0.724928
# 4                 16.378601         3.171714                0.651629
# ..                      ...              ...                     ...
# 255               31.519219         0.521531                0.210052
# 271               41.497323         2.114784                0.464056
# 272               24.161467         0.489232                0.594547
# 273               26.221982         5.016520                1.017654
# 274               22.240275         5.276193                0.244727
#
#      mediumprobacloudspercentage  highprobacloudspercentage  \
# 0                      10.099245                  33.018008
# 1                      16.906878                  47.996762
# 2                       0.034821                   0.010938
# 3                       4.156121                   3.948716
# 4                       8.204094                   3.257432
# ..                           ...                        ...
# 255                     0.000654                   0.000149
# 271                     1.451953                   2.036002
# 272                     6.919496                   2.004227
# 273                     5.901754                   9.609088
# 274                    11.712108                   0.589670
#
#      snowicepercentage  cloudcoverpercentage  \
# 0             0.026568             45.573053
# 1             0.069854             66.221929
# 2             0.000000              0.088359
# 3             0.000010             17.916168
# 4             0.207642             22.542572
# ..                 ...                   ...
# 255           0.157995              0.002512
# 271           1.268619              4.226599
# 272           0.055658             20.320608
# 273           1.814948             17.254439
# 274           0.032794             35.020816
#
#                                   level1cpdiidentifier  \
# 0    S2B_OPER_MSI_L1C_TL_2BPS_20220523T121553_A0272...
# 1    S2B_OPER_MSI_L1C_TL_2BPS_20220523T121553_A0272...
# 2    S2B_OPER_MSI_L1C_TL_2BPS_20220523T121553_A0272...
# 3    S2B_OPER_MSI_L1C_TL_2BPS_20220523T121553_A0272...
# 4    S2A_OPER_MSI_L1C_TL_ATOS_20220521T154108_A0360...
# ..                                                 ...
# 255  S2A_OPER_MSI_L1C_TL_VGS4_20220418T111345_A0356...
# 271  S2B_OPER_MSI_L1C_TL_VGS2_20220416T160249_A0266...
# 272  S2B_OPER_MSI_L1C_TL_VGS2_20220416T160249_A0266...
# 273  S2B_OPER_MSI_L1C_TL_VGS2_20220416T160249_A0266...
# 274  S2B_OPER_MSI_L1C_TL_VGS2_20220416T160249_A0266...
#
#                                           gmlfootprint  \
# 0    <gml:Polygon srsName="http://www.opengis.net/g...
# 1    <gml:Polygon srsName="http://www.opengis.net/g...
# 2    <gml:Polygon srsName="http://www.opengis.net/g...
# 3    <gml:Polygon srsName="http://www.opengis.net/g...
# 4    <gml:Polygon srsName="http://www.opengis.net/g...
# ..                                                 ...
# 255  <gml:Polygon srsName="http://www.opengis.net/g...
# 271  <gml:Polygon srsName="http://www.opengis.net/g...
# 272  <gml:Polygon srsName="http://www.opengis.net/g...
# 273  <gml:Polygon srsName="http://www.opengis.net/g...
# 274  <gml:Polygon srsName="http://www.opengis.net/g...
#
#                                              footprint format  \
# 0    MULTIPOLYGON (((10.394253870988432 45.05674859...   SAFE
# 1    MULTIPOLYGON (((11.663504207768549 45.03419014...   SAFE
# 2    MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 3    MULTIPOLYGON (((11.622741209146946 44.13525072...   SAFE
# 4    MULTIPOLYGON (((10.994687999700904 45.04571307...   SAFE
# ..                                                 ...    ...
# 255  MULTIPOLYGON (((11.622741209146946 44.13525072...   SAFE
# 271  MULTIPOLYGON (((10.394253870988432 45.05674859...   SAFE
# 272  MULTIPOLYGON (((10.628086307717366 44.15211922...   SAFE
# 273  MULTIPOLYGON (((10.992362397033203 45.04575314...   SAFE
# 274  MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
#
#      processingbaseline platformname  \
# 0                   4.0   Sentinel-2
# 1                   4.0   Sentinel-2
# 2                   4.0   Sentinel-2
# 3                   4.0   Sentinel-2
# 4                   4.0   Sentinel-2
# ..                  ...          ...
# 255                 4.0   Sentinel-2
# 271                 4.0   Sentinel-2
# 272                 4.0   Sentinel-2
# 273                 4.0   Sentinel-2
# 274                 4.0   Sentinel-2
#
#                                               filename  \
# 0    S2B_MSIL2A_20220523T100559_N0400_R022_T32TNR_2...
# 1    S2B_MSIL2A_20220523T100559_N0400_R022_T32TPR_2...
# 2    S2B_MSIL2A_20220523T100559_N0400_R022_T32TNQ_2...
# 3    S2B_MSIL2A_20220523T100559_N0400_R022_T32TPQ_2...
# 4    S2A_MSIL2A_20220521T101601_N0400_R065_T32TPR_2...
# ..                                                 ...
# 255  S2A_MSIL2A_20220418T100601_N0400_R022_T32TPQ_2...
# 271  S2B_MSIL2A_20220416T101559_N0400_R065_T32TNR_2...
# 272  S2B_MSIL2A_20220416T101559_N0400_R065_T32TPQ_2...
# 273  S2B_MSIL2A_20220416T101559_N0400_R065_T32TPR_2...
# 274  S2B_MSIL2A_20220416T101559_N0400_R065_T32TNQ_2...
#
#                 instrumentname instrumentshortname       size  \
# 0    Multi-Spectral Instrument                 MSI  521.30 MB
# 1    Multi-Spectral Instrument                 MSI    1.04 GB
# 2    Multi-Spectral Instrument                 MSI  802.36 MB
# 3    Multi-Spectral Instrument                 MSI    1.12 GB
# 4    Multi-Spectral Instrument                 MSI  821.00 MB
# ..                         ...                 ...        ...
# 255  Multi-Spectral Instrument                 MSI    1.13 GB
# 271  Multi-Spectral Instrument                 MSI    1.15 GB
# 272  Multi-Spectral Instrument                 MSI  521.69 MB
# 273  Multi-Spectral Instrument                 MSI  834.01 MB
# 274  Multi-Spectral Instrument                 MSI    1.05 GB
#
#                            s2datatakeid producttype platformidentifier  \
# 0    GS2B_20220523T100559_027218_N04.00     S2MSI2A          2017-013A
# 1    GS2B_20220523T100559_027218_N04.00     S2MSI2A          2017-013A
# 2    GS2B_20220523T100559_027218_N04.00     S2MSI2A          2017-013A
# 3    GS2B_20220523T100559_027218_N04.00     S2MSI2A          2017-013A
# 4    GS2A_20220521T101601_036098_N04.00     S2MSI2A          2015-028A
# ..                                  ...         ...                ...
# 255  GS2A_20220418T100601_035626_N04.00     S2MSI2A          2015-028A
# 271  GS2B_20220416T101559_026689_N04.00     S2MSI2A          2017-013A
# 272  GS2B_20220416T101559_026689_N04.00     S2MSI2A          2017-013A
# 273  GS2B_20220416T101559_026689_N04.00     S2MSI2A          2017-013A
# 274  GS2B_20220416T101559_026689_N04.00     S2MSI2A          2017-013A
#
#     orbitdirection platformserialidentifier processinglevel  \
# 0       DESCENDING              Sentinel-2B        Level-2A
# 1       DESCENDING              Sentinel-2B        Level-2A
# 2       DESCENDING              Sentinel-2B        Level-2A
# 3       DESCENDING              Sentinel-2B        Level-2A
# 4       DESCENDING              Sentinel-2A        Level-2A
# ..             ...                      ...             ...
# 255     DESCENDING              Sentinel-2A        Level-2A
# 271     DESCENDING              Sentinel-2B        Level-2A
# 272     DESCENDING              Sentinel-2B        Level-2A
# 273     DESCENDING              Sentinel-2B        Level-2A
# 274     DESCENDING              Sentinel-2B        Level-2A
#
#                                    datastripidentifier  \
# 0    S2B_OPER_MSI_L2A_DS_2BPS_20220523T132335_S2022...
# 1    S2B_OPER_MSI_L2A_DS_2BPS_20220523T132335_S2022...
# 2    S2B_OPER_MSI_L2A_DS_2BPS_20220523T132335_S2022...
# 3    S2B_OPER_MSI_L2A_DS_2BPS_20220523T132335_S2022...
# 4    S2A_OPER_MSI_L2A_DS_ATOS_20220521T181716_S2022...
# ..                                                 ...
# 255  S2A_OPER_MSI_L2A_DS_VGS4_20220418T132615_S2022...
# 271  S2B_OPER_MSI_L2A_DS_VGS2_20220416T175100_S2022...
# 272  S2B_OPER_MSI_L2A_DS_VGS2_20220416T175100_S2022...
# 273  S2B_OPER_MSI_L2A_DS_VGS2_20220416T175100_S2022...
# 274  S2B_OPER_MSI_L2A_DS_VGS2_20220416T175100_S2022...
#
#                                      granuleidentifier  \
# 0    S2B_OPER_MSI_L2A_TL_2BPS_20220523T132335_A0272...
# 1    S2B_OPER_MSI_L2A_TL_2BPS_20220523T132335_A0272...
# 2    S2B_OPER_MSI_L2A_TL_2BPS_20220523T132335_A0272...
# 3    S2B_OPER_MSI_L2A_TL_2BPS_20220523T132335_A0272...
# 4    S2A_OPER_MSI_L2A_TL_ATOS_20220521T181716_A0360...
# ..                                                 ...
# 255  S2A_OPER_MSI_L2A_TL_VGS4_20220418T132615_A0356...
# 271  S2B_OPER_MSI_L2A_TL_VGS2_20220416T175100_A0266...
# 272  S2B_OPER_MSI_L2A_TL_VGS2_20220416T175100_A0266...
# 273  S2B_OPER_MSI_L2A_TL_VGS2_20220416T175100_A0266...
# 274  S2B_OPER_MSI_L2A_TL_VGS2_20220416T175100_A0266...
#
#                                             identifier  \
# 0    S2B_MSIL2A_20220523T100559_N0400_R022_T32TNR_2...
# 1    S2B_MSIL2A_20220523T100559_N0400_R022_T32TPR_2...
# 2    S2B_MSIL2A_20220523T100559_N0400_R022_T32TNQ_2...
# 3    S2B_MSIL2A_20220523T100559_N0400_R022_T32TPQ_2...
# 4    S2A_MSIL2A_20220521T101601_N0400_R065_T32TPR_2...
# ..                                                 ...
# 255  S2A_MSIL2A_20220418T100601_N0400_R022_T32TPQ_2...
# 271  S2B_MSIL2A_20220416T101559_N0400_R065_T32TNR_2...
# 272  S2B_MSIL2A_20220416T101559_N0400_R065_T32TPQ_2...
# 273  S2B_MSIL2A_20220416T101559_N0400_R065_T32TPR_2...
# 274  S2B_MSIL2A_20220416T101559_N0400_R065_T32TNQ_2...
#
#                                      uuid  \
# 0    af2c4906-8bc3-4c56-a2ac-dc357ced7257
# 1    b7dfc243-9d67-42f5-b07b-92780ea92fcf
# 2    a3d9136b-b05a-4efc-bec4-58bfeb8bf46d
# 3    397a0632-eba0-44fd-943e-ef32cd8a78e9
# 4    8034f16f-c8e1-4281-8da5-90f201b1f521
# ..                                    ...
# 255  e1264baf-897e-4314-99fe-6cffa678fc57
# 271  b81e126e-7a4b-46e3-8cab-e1138e8fa15f
# 272  2d7d9671-75ef-466d-9e33-7893a32600e7
# 273  527e45c6-7944-48e9-8ee2-2c754e36e023
# 274  d74bae61-ba12-4135-8be9-3e6c48184c54
#
#                                                   path
# 0    ../sentinelcache/products/2022-05-23/af2c4906-...
# 1    ../sentinelcache/products/2022-05-23/b7dfc243-...
# 2    ../sentinelcache/products/2022-05-23/a3d9136b-...
# 3    ../sentinelcache/products/2022-05-23/397a0632-...
# 4    ../sentinelcache/products/2022-05-21/8034f16f-...
# ..                                                 ...
# 255  ../sentinelcache/products/2022-04-18/e1264baf-...
# 271  ../sentinelcache/products/2022-04-16/b81e126e-...
# 272  ../sentinelcache/products/2022-04-16/2d7d9671-...
# 273  ../sentinelcache/products/2022-04-16/527e45c6-...
# 274  ../sentinelcache/products/2022-04-16/d74bae61-...
#
# [140 rows x 43 columns]

# %% [markdown]
# Select one area

# %%
# Cycle over all of the polygons ( by hand )
footprint = df_all["footprint"].unique()[7]

df_sel = df_all[df_all["footprint"] == footprint]
df_sel = df_sel.sort_values("generationdate", ascending=True)
display(df_sel)

# Check the polygon centroid
P = shapely.wkt.loads(footprint)
center = P.centroid.wkt
center = center.replace("POINT ", "")
center = center.replace("(", "")
center = center.replace(")", "")
center = center.replace(" ", "_")
print(f"images_{center}")

Path(f"images_{center}").mkdir(parents=True, exist_ok=True)

for indx, row in df_sel.iterrows():

    path_to_tiff = row["path"]
    # print(path_to_tiff)
    date = row["generationdate"]
    date_str = date.replace(" ", "_").replace(":", "_")

    if pd.notnull(path_to_tiff):

        img = rasterio.open(path_to_tiff)
        img_data = img.read()[0]

        # if footprint == df_all["footprint"].unique()[2]:
        #     # Crop data
        #     img_data = img_data[200:3000, :]
        #     plt.figure(figsize=(20, 6))
        # else:
        plt.figure(figsize=(20,20))
        # plt.title(f"Date: {date}")
        plt.imshow(img_data, cmap="twilight", vmin=800, vmax=16000)
        plt.axis("off")
        plt.tight_layout()
        plt.savefig(f"images_{center}/{date_str}.png", dpi=100)
        print(f"images_{center}/{date_str}.png")
        # plt.colorbar()
        plt.close("all")
# Out:
#                                                  title  \
# 12   S2A_MSIL2A_20220411T101601_N0400_R065_T32TNQ_2...
# 274  S2B_MSIL2A_20220416T101559_N0400_R065_T32TNQ_2...
# 19   S2A_MSIL2A_20220501T101601_N0400_R065_T32TNQ_2...
# 110  S2A_MSIL2A_20220511T101601_N0400_R065_T32TNQ_2...
# 60                17.210272         6.278991                0.131280
# 98                19.846374         6.089486                0.060982
#
#      mediumprobacloudspercentage  highprobacloudspercentage  \
# 12                      0.058168                   0.006758
# 274                    11.712108                   0.589670
# 19                     41.019228                  25.048906
# 110                     0.961636                   1.203092
# 70                      0.629457                   0.377411
# 7                       2.459156                   1.778488
# 83                     20.017777                  47.023311
# 31                      0.339820                   0.691136
# 122                     6.187843                   5.805117
# 152                     0.748674                   0.591538
# 51                      8.918716                  10.154498
# 85                      0.421133                   0.213440
# 117                     1.578167                   1.678538
# 60                      3.134562                   4.041012
# 98                      0.239581                   0.113998
#
#      snowicepercentage  cloudcoverpercentage  \
# 12            0.217600              6.401561
# 274           0.032794             35.020816
# 19            0.000000             79.421985
# 110           0.000494             27.806130
# 70            0.000285              9.524427
# 7             0.000007             14.519013
# 83            0.000000             78.379661
# 31            0.000000              1.425320
# 122           0.000000             39.949214
# 152           0.000000              1.341568
# 51            0.000003             19.088039
# 85            0.000000              0.642878
# 117           0.000173              3.268781
# 60            0.000654              7.176622
# 98            0.000000              0.437676
#
#                                   level1cpdiidentifier  \
# 12   S2A_OPER_MSI_L1C_TL_VGS2_20220411T124038_A0355...
# 274  S2B_OPER_MSI_L1C_TL_VGS2_20220416T160249_A0266...
# 19   S2A_OPER_MSI_L1C_TL_ATOS_20220501T122254_A0358...
# 110  S2A_OPER_MSI_L1C_TL_ATOS_20220511T135949_A0359...
# 70   S2B_OPER_MSI_L1C_TL_2BPS_20220516T122644_A0271...
# 7    S2A_OPER_MSI_L1C_TL_ATOS_20220521T154108_A0360...
# 83   S2B_OPER_MSI_L1C_TL_2BPS_20220605T123553_A0274...
# 31   S2A_OPER_MSI_L1C_TL_ATOS_20220610T153906_A0363...
# 122  S2B_OPER_MSI_L1C_TL_2BPS_20220615T122549_A0275...
# 152  S2A_OPER_MSI_L1C_TL_ATOS_20220620T140020_A0365...
# 51   S2B_OPER_MSI_L1C_TL_2BPS_20220625T123127_A0276...
# 85   S2A_OPER_MSI_L1C_TL_ATOS_20220630T153904_A0366...
# 117  S2B_OPER_MSI_L1C_TL_2BPS_20220705T123007_A0278...
# 60   S2A_OPER_MSI_L1C_TL_ATOS_20220710T140211_A0368...
# 98   S2B_OPER_MSI_L1C_TL_2BPS_20220715T122556_A0279...
#
#                                           gmlfootprint  \
# 12   <gml:Polygon srsName="http://www.opengis.net/g...
# 274  <gml:Polygon srsName="http://www.opengis.net/g...
# 19   <gml:Polygon srsName="http://www.opengis.net/g...
# 110  <gml:Polygon srsName="http://www.opengis.net/g...
# 70   <gml:Polygon srsName="http://www.opengis.net/g...
# 7    <gml:Polygon srsName="http://www.opengis.net/g...
# 83   <gml:Polygon srsName="http://www.opengis.net/g...
# 31   <gml:Polygon srsName="http://www.opengis.net/g...
# 122  <gml:Polygon srsName="http://www.opengis.net/g...
# 152  <gml:Polygon srsName="http://www.opengis.net/g...
# 51   <gml:Polygon srsName="http://www.opengis.net/g...
# 85   <gml:Polygon srsName="http://www.opengis.net/g...
# 117  <gml:Polygon srsName="http://www.opengis.net/g...
# 60   <gml:Polygon srsName="http://www.opengis.net/g...
# 98   <gml:Polygon srsName="http://www.opengis.net/g...
#
#                                              footprint format  \
# 12   MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 274  MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 19   MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 110  MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 70   MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 7    MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 83   MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 31   MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 122  MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 152  MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 51   MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 85   MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 117  MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 60   MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
# 98   MULTIPOLYGON (((10.37289400045457 44.157116557...   SAFE
#
#      processingbaseline platformname  \
# 12                  4.0   Sentinel-2
# 274                 4.0   Sentinel-2
# 19                  4.0   Sentinel-2
# 110                 4.0   Sentinel-2
# 70                  4.0   Sentinel-2
# 7                   4.0   Sentinel-2
# 83                  4.0   Sentinel-2
# 31                  4.0   Sentinel-2
# 122                 4.0   Sentinel-2
# 152                 4.0   Sentinel-2
# 51                  4.0   Sentinel-2
# 85                  4.0   Sentinel-2
# 117                 4.0   Sentinel-2
# 60                  4.0   Sentinel-2
# 98                  4.0   Sentinel-2
#
#                                               filename  \
# 12   S2A_MSIL2A_20220411T101601_N0400_R065_T32TNQ_2...
# 274  S2B_MSIL2A_20220416T101559_N0400_R065_T32TNQ_2...
# 19   S2A_MSIL2A_20220501T101601_N0400_R065_T32TNQ_2...
# 110  S2A_MSIL2A_20220511T101601_N0400_R065_T32TNQ_2...
# 70   S2B_MSIL2A_20220516T101559_N0400_R065_T32TNQ_2...
# 7    S2A_MSIL2A_20220521T101601_N0400_R065_T32TNQ_2...
# 83   S2B_MSIL2A_20220605T101559_N0400_R065_T32TNQ_2...
# 31   S2A_MSIL2A_20220610T101611_N0400_R065_T32TNQ_2...
# 122  S2B_MSIL2A_20220615T101559_N0400_R065_T32TNQ_2...
# 152  S2A_MSIL2A_20220620T102041_N0400_R065_T32TNQ_2...
# 51   S2B_MSIL2A_20220625T101559_N0400_R065_T32TNQ_2...
# 85   S2A_MSIL2A_20220630T102041_N0400_R065_T32TNQ_2...
# 117  S2B_MSIL2A_20220705T101559_N0400_R065_T32TNQ_2...
# 60   S2A_MSIL2A_20220710T101611_N0400_R065_T32TNQ_2...
# 98   S2B_MSIL2A_20220715T101559_N0400_R065_T32TNQ_2...
#
#                 instrumentname instrumentshortname       size  \
# 12   Multi-Spectral Instrument                 MSI    1.11 GB
# 274  Multi-Spectral Instrument                 MSI    1.05 GB
# 19   Multi-Spectral Instrument                 MSI  964.96 MB
# 110  Multi-Spectral Instrument                 MSI    1.07 GB
# 70   Multi-Spectral Instrument                 MSI    1.10 GB
# 7    Multi-Spectral Instrument                 MSI    1.10 GB
# 83   Multi-Spectral Instrument                 MSI  951.51 MB
# 31   Multi-Spectral Instrument                 MSI    1.11 GB
# 122  Multi-Spectral Instrument                 MSI    1.07 GB
# 152  Multi-Spectral Instrument                 MSI    1.11 GB
# 51   Multi-Spectral Instrument                 MSI    1.11 GB
# 85   Multi-Spectral Instrument                 MSI    1.11 GB
# 117  Multi-Spectral Instrument                 MSI    1.11 GB
# 60   Multi-Spectral Instrument                 MSI    1.12 GB
# 98   Multi-Spectral Instrument                 MSI    1.11 GB
#
#                            s2datatakeid producttype platformidentifier  \
# 12   GS2A_20220411T101601_035526_N04.00     S2MSI2A          2015-028A
# 274  GS2B_20220416T101559_026689_N04.00     S2MSI2A          2017-013A
# 19   GS2A_20220501T101601_035812_N04.00     S2MSI2A          2015-028A
# 110  GS2A_20220511T101601_035955_N04.00     S2MSI2A          2015-028A
# 70   GS2B_20220516T101559_027118_N04.00     S2MSI2A          2017-013A
# 7    GS2A_20220521T101601_036098_N04.00     S2MSI2A          2015-028A
# 83   GS2B_20220605T101559_027404_N04.00     S2MSI2A          2017-013A
# 31   GS2A_20220610T101611_036384_N04.00     S2MSI2A          2015-028A
# 122  GS2B_20220615T101559_027547_N04.00     S2MSI2A          2017-013A
# 152  GS2A_20220620T102041_036527_N04.00     S2MSI2A          2015-028A
# 51   GS2B_20220625T101559_027690_N04.00     S2MSI2A          2017-013A
# 85   GS2A_20220630T102041_036670_N04.00     S2MSI2A          2015-028A
# 117  GS2B_20220705T101559_027833_N04.00     S2MSI2A          2017-013A
# 60   GS2A_20220710T101611_036813_N04.00     S2MSI2A          2015-028A
# 98   GS2B_20220715T101559_027976_N04.00     S2MSI2A          2017-013A
#
#     orbitdirection platformserialidentifier processinglevel  \
# 12      DESCENDING              Sentinel-2A        Level-2A
# 274     DESCENDING              Sentinel-2B        Level-2A
# 19       ASCENDING              Sentinel-2A        Level-2A
# 110     DESCENDING              Sentinel-2A        Level-2A
# 70      DESCENDING              Sentinel-2B        Level-2A
# 7       DESCENDING              Sentinel-2A        Level-2A
# 83      DESCENDING              Sentinel-2B        Level-2A
# 31      DESCENDING              Sentinel-2A        Level-2A
# 122     DESCENDING              Sentinel-2B        Level-2A
# 152     DESCENDING              Sentinel-2A        Level-2A
# 51      DESCENDING              Sentinel-2B        Level-2A
# 85      DESCENDING              Sentinel-2A        Level-2A
# 117     DESCENDING              Sentinel-2B        Level-2A
# 60      DESCENDING              Sentinel-2A        Level-2A
# 98      DESCENDING              Sentinel-2B        Level-2A
#
#                                    datastripidentifier  \
# 12   S2A_OPER_MSI_L2A_DS_VGS2_20220411T135651_S2022...
# 274  S2B_OPER_MSI_L2A_DS_VGS2_20220416T175100_S2022...
# 19   S2A_OPER_MSI_L2A_DS_ATOS_20220501T154819_S2022...
# 110  S2A_OPER_MSI_L2A_DS_ATOS_20220511T174519_S2022...
# 70   S2B_OPER_MSI_L2A_DS_2BPS_20220516T133430_S2022...
# 7    S2A_OPER_MSI_L2A_DS_ATOS_20220521T181716_S2022...
# 83   S2B_OPER_MSI_L2A_DS_2BPS_20220605T134213_S2022...
# 31   S2A_OPER_MSI_L2A_DS_ATOS_20220610T181610_S2022...
# 122  S2B_OPER_MSI_L2A_DS_2BPS_20220615T132635_S2022...
# 152  S2A_OPER_MSI_L2A_DS_ATOS_20220620T162319_S2022...
# 51   S2B_OPER_MSI_L2A_DS_2BPS_20220625T131754_S2022...
# 85   S2A_OPER_MSI_L2A_DS_ATOS_20220630T182013_S2022...
# 117  S2B_OPER_MSI_L2A_DS_2BPS_20220705T131726_S2022...
# 60   S2A_OPER_MSI_L2A_DS_ATOS_20220710T165533_S2022...
# 98   S2B_OPER_MSI_L2A_DS_2BPS_20220715T133111_S2022...
#
#                                      granuleidentifier  \
# 12   S2A_OPER_MSI_L2A_TL_VGS2_20220411T135651_A0355...
# 274  S2B_OPER_MSI_L2A_TL_VGS2_20220416T175100_A0266...
# 19   S2A_OPER_MSI_L2A_TL_ATOS_20220501T154819_A0358...
# 110  S2A_OPER_MSI_L2A_TL_ATOS_20220511T174519_A0359...
# 70   S2B_OPER_MSI_L2A_TL_2BPS_20220516T133430_A0271...
# 7    S2A_OPER_MSI_L2A_TL_ATOS_20220521T181716_A0360...
# 83   S2B_OPER_MSI_L2A_TL_2BPS_20220605T134213_A0274...
# 31   S2A_OPER_MSI_L2A_TL_ATOS_20220610T181610_A0363...
# 122  S2B_OPER_MSI_L2A_TL_2BPS_20220615T132635_A0275...
# 152  S2A_OPER_MSI_L2A_TL_ATOS_20220620T162319_A0365...
# 51   S2B_OPER_MSI_L2A_TL_2BPS_20220625T131754_A0276...
# 85   S2A_OPER_MSI_L2A_TL_ATOS_20220630T182013_A0366...
# 117  S2B_OPER_MSI_L2A_TL_2BPS_20220705T131726_A0278...
# 60   S2A_OPER_MSI_L2A_TL_ATOS_20220710T165533_A0368...
# 98   S2B_OPER_MSI_L2A_TL_2BPS_20220715T133111_A0279...
#
#                                             identifier  \
# 12   S2A_MSIL2A_20220411T101601_N0400_R065_T32TNQ_2...
# 274  S2B_MSIL2A_20220416T101559_N0400_R065_T32TNQ_2...
# 19   S2A_MSIL2A_20220501T101601_N0400_R065_T32TNQ_2...
# 110  S2A_MSIL2A_20220511T101601_N0400_R065_T32TNQ_2...
# 70   S2B_MSIL2A_20220516T101559_N0400_R065_T32TNQ_2...
# 7    S2A_MSIL2A_20220521T101601_N0400_R065_T32TNQ_2...
# 83   S2B_MSIL2A_20220605T101559_N0400_R065_T32TNQ_2...
# 31   S2A_MSIL2A_20220610T101611_N0400_R065_T32TNQ_2...
# 122  S2B_MSIL2A_20220615T101559_N0400_R065_T32TNQ_2...
# 152  S2A_MSIL2A_20220620T102041_N0400_R065_T32TNQ_2...
# 51   S2B_MSIL2A_20220625T101559_N0400_R065_T32TNQ_2...
# 85   S2A_MSIL2A_20220630T102041_N0400_R065_T32TNQ_2...
# 117  S2B_MSIL2A_20220705T101559_N0400_R065_T32TNQ_2...
# 60   S2A_MSIL2A_20220710T101611_N0400_R065_T32TNQ_2...
# 98   S2B_MSIL2A_20220715T101559_N0400_R065_T32TNQ_2...
#
#                                      uuid  \
# 12   9b8d26fe-d2bf-499e-86da-003e582e61e5
# 274  d74bae61-ba12-4135-8be9-3e6c48184c54
# 19   b8516a55-fbbb-400b-b2f1-ad53bb410f9a
# 110  605785d7-01a1-4077-88e5-cb0dbb5dc02f
# 70   b0365cd0-1a1c-4f91-a0be-c49be899f5e9
# 7    2d72b106-a01f-469f-9670-3b0f71de3ae9
# 83   9088b32e-7495-4669-b933-7e24116e6b69
# 31   3abd57ea-f0dd-4e01-800a-7141da4e47fa
# 122  0ecfb7ed-4bcb-4c9a-9ebc-1262b5ee89c1
# 152  5fd4fa14-42aa-4a7b-9469-19fd774ffe8a
# 51   bf53f356-6a7c-44b8-bec1-0f688b871478
# 85   dd1b9c02-62f0-414c-9234-5792dc2de66d
# 117  8d97ee33-a83c-4f25-b4a3-ba9557d52185
# 60   20df6448-d4cd-4006-b8f0-1b280db291ed
# 98   1cab54c7-59af-46c2-84f2-77678309e11c
#
#                                                   path
# 12   ../sentinelcache/products/2022-04-11/9b8d26fe-...
# 274  ../sentinelcache/products/2022-04-16/d74bae61-...
# 19   ../sentinelcache/products/2022-05-01/b8516a55-...
# 110  ../sentinelcache/products/2022-05-11/605785d7-...
# 70   ../sentinelcache/products/2022-05-16/b0365cd0-...
# 7    ../sentinelcache/products/2022-05-21/2d72b106-...
# 83   ../sentinelcache/products/2022-06-05/9088b32e-...
# 31   ../sentinelcache/products/2022-06-10/3abd57ea-...
# 122  ../sentinelcache/products/2022-06-15/0ecfb7ed-...
# 152  ../sentinelcache/products/2022-06-20/5fd4fa14-...
# 51   ../sentinelcache/products/2022-06-25/bf53f356-...
# 85   ../sentinelcache/products/2022-06-30/dd1b9c02-...
# 117  ../sentinelcache/products/2022-07-05/8d97ee33-...
# 60                                                 NaN
# 98   ../sentinelcache/products/2022-07-15/1cab54c7-...
# images_9.692199846052773_44.65680402553783
# images_9.692199846052773_44.65680402553783/2022-04-11_13_56_51.png
# images_9.692199846052773_44.65680402553783/2022-04-16_17_51_00.png
# images_9.692199846052773_44.65680402553783/2022-05-01_15_48_19.png
# images_9.692199846052773_44.65680402553783/2022-05-11_17_45_19.png
# images_9.692199846052773_44.65680402553783/2022-05-16_13_34_30.png
# images_9.692199846052773_44.65680402553783/2022-05-21_18_17_16.png
# images_9.692199846052773_44.65680402553783/2022-06-05_13_42_13.png
# images_9.692199846052773_44.65680402553783/2022-06-10_18_16_10.png
# images_9.692199846052773_44.65680402553783/2022-06-15_13_26_35.png
# images_9.692199846052773_44.65680402553783/2022-06-20_16_23_19.png
# images_9.692199846052773_44.65680402553783/2022-06-25_13_17_54.png
# images_9.692199846052773_44.65680402553783/2022-06-30_18_20_13.png
# images_9.692199846052773_44.65680402553783/2022-07-05_13_17_26.png
# images_9.692199846052773_44.65680402553783/2022-07-15_13_31_11.png

# %%
footprint = df_all["footprint"].unique()[5]

# Check the polygon centroid
P = shapely.wkt.loads(footprint)
center = P.centroid.wkt
center = center.replace("POINT ", "")
center = center.replace("(", "")
center = center.replace(")", "")
center = center.replace(" ", "_")
print(f"images_{center}")
# Out:
# images_9.703162156092771_45.55653064058514
